# %% [markdown]
# # QURAN & NLP

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("../data/Quran.csv")
df.head()
# Out:
#    Unnamed: 0  SurahNo  AyahNo  \
# 0           0        1       1
# 1           1        1       2
# 2           2        1       3
# 3           3        1       4
# 4           4        1       5
#
#                                   EnglishTranslation  \
# 0  In the name of Allah, Most Gracious, Most Merc...
# 1  Praise be to Allah, the Cherisher and Sustaine...
# 2                      Most Gracious, Most Merciful;
# 3                     Master of the Day of Judgment.
# 4         Thee do we worship, and Thine aid we seek.
#
#                                              Tafseer
# 0  b'["1 One of the many practices taught by Isla...
# 1  b'2. As we have already explained, the charact...
# 2  b'4. Whenever we are deeply impressed by the g...
# 3  b'5. God will be the Lord of the Day when all ...
# 4  b'6. The term ibadah is used in three sense: (...

# %%
df = df[["SurahNo", "AyahNo", "EnglishTranslation", "Tafseer"]]
df.head()
# Out:
#    SurahNo  AyahNo                                 EnglishTranslation  \
# 0        1       1  In the name of Allah, Most Gracious, Most Merc...
# 1        1       2  Praise be to Allah, the Cherisher and Sustaine...
# 2        1       3                      Most Gracious, Most Merciful;
# 3        1       4                     Master of the Day of Judgment.
# 4        1       5         Thee do we worship, and Thine aid we seek.
#
#                                              Tafseer
# 0  b'["1 One of the many practices taught by Isla...
# 1  b'2. As we have already explained, the charact...
# 2  b'4. Whenever we are deeply impressed by the g...
# 3  b'5. God will be the Lord of the Day when all ...
# 4  b'6. The term ibadah is used in three sense: (...

# %%
arabic =  pd.read_csv("../data/Arabic.csv")
arabic.head()
# Out:
#           Name  Surah  Ayat                                    Arabic
# 0  The Opening      1     1        بِسمِ ٱلله الرَّحْمٰنِ الرَّحِيـمِ
# 1  The Opening      1     2      ٱلْحَمْدُ للَّهِ رَبِّ ٱلْعَالَمِينَ
# 2  The Opening      1     3                   ٱلرَّحْمـٰنِ ٱلرَّحِيمِ
# 3  The Opening      1     4                  مَـٰلِكِ يَوْمِ ٱلدِّينِ
# 4  The Opening      1     5  إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ

# %%
df.rename(columns = {"SurahNo":"Surah", "AyahNo":"Ayat"}, inplace = True)

# %%
df.head()
# Out:
#    Surah  Ayat                                 EnglishTranslation  \
# 0      1     1  In the name of Allah, Most Gracious, Most Merc...
# 1      1     2  Praise be to Allah, the Cherisher and Sustaine...
# 2      1     3                      Most Gracious, Most Merciful;
# 3      1     4                     Master of the Day of Judgment.
# 4      1     5         Thee do we worship, and Thine aid we seek.
#
#                                              Tafseer
# 0  b'["1 One of the many practices taught by Isla...
# 1  b'2. As we have already explained, the charact...
# 2  b'4. Whenever we are deeply impressed by the g...
# 3  b'5. God will be the Lord of the Day when all ...
# 4  b'6. The term ibadah is used in three sense: (...

# %%
df = arabic.merge(
    df,
    left_on=['Surah', 'Ayat'],
    right_on=['Surah', 'Ayat'],
    how='inner')

# %%
df.head()
# Out:
#           Name  Surah  Ayat                                    Arabic  \
# 0  The Opening      1     1        بِسمِ ٱلله الرَّحْمٰنِ الرَّحِيـمِ
# 1  The Opening      1     2      ٱلْحَمْدُ للَّهِ رَبِّ ٱلْعَالَمِينَ
# 2  The Opening      1     3                   ٱلرَّحْمـٰنِ ٱلرَّحِيمِ
# 3  The Opening      1     4                  مَـٰلِكِ يَوْمِ ٱلدِّينِ
# 4  The Opening      1     5  إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ
#
#                                   EnglishTranslation  \
# 0  In the name of Allah, Most Gracious, Most Merc...
# 1  Praise be to Allah, the Cherisher and Sustaine...
# 2                      Most Gracious, Most Merciful;
# 3                     Master of the Day of Judgment.
# 4         Thee do we worship, and Thine aid we seek.
#
#                                              Tafseer
# 0  b'["1 One of the many practices taught by Isla...
# 1  b'2. As we have already explained, the charact...
# 2  b'4. Whenever we are deeply impressed by the g...
# 3  b'5. God will be the Lord of the Day when all ...
# 4  b'6. The term ibadah is used in three sense: (...

# %%
arabic = []
text=[]
for index, row in df.iterrows():
    arabic.append(row['Arabic'])
    t = ""
    t += row['Name'] + "|" + str(row['Surah'])+"|"+str(row['Ayat']) + "|" + row['EnglishTranslation'] + "|" + row['Tafseer']  
    text.append(t)

# %%
len(text)
# Out:
# 6236

# %%
text[0]
# Out:
# 'The Opening|1|1|In the name of Allah, Most Gracious, Most Merciful.|b\'["1 One of the many practices taught by Islam is that its followers should begin their activities in the name of God. This principle, if consciously and earnestly followed, will necessarily yield three beneficial results. First, one will be able to restrain oneself from many misdeed, since the habit of pronouncing the name of God is bound to make one wonder when about to commit some offence how such an act can be reconciled with the saying of God\\x92s holy name. Second, if a man pronounces the name of God before starting good and legitimate tasks, this act will ensue that both his starting point and his mental orientation are sound. Third \\x96 and this is the most important benefit \\x96 when a man begins something by pronouncing God\\x92s name, he will enjoy God\\x92s support and succour; God will bless his efforts and protect him from the machinations and temptation of Satan. For whenever man turns to God, God turns to him as well.\''

# %%
arabic[0]
# Out:
# 'بِسمِ ٱلله الرَّحْمٰنِ الرَّحِيـمِ'

# %% [markdown]
# ## Putting data in variables

# %%
surah = []
surah_english = []
ayat = []
translation = []
tafseer = []
tafseer_ayat = []
curr = 1
for i in range(len(text)):
    if int(text[i].split("|")[1]) != curr:
        if len(ayat)>0:
            surah.append(ayat)
            tafseer.append(tafseer_ayat)
            surah_english.append(translation)
        ayat = []
        tafseer_ayat = []
        translation = []
        curr+=1
    tafseer_ayat.append(text[i].split("|")[-1])
    ayat.append(arabic[i])
    translation.append(text[i].split("|")[-2])
surah.append(ayat)
tafseer.append(tafseer_ayat)
surah_english.append(translation)

# %%
surah[0]
# Out:
# ['بِسمِ ٱلله الرَّحْمٰنِ الرَّحِيـمِ',
#  'ٱلْحَمْدُ للَّهِ رَبِّ ٱلْعَالَمِينَ',
#  'ٱلرَّحْمـٰنِ ٱلرَّحِيمِ',
#  'مَـٰلِكِ يَوْمِ ٱلدِّينِ',
#  'إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ',
#  'ٱهْدِنَا ٱلصِّرَاطَ ٱلْمُسْتَقِيمَ',
#  'صِرَاطَ ٱلَّذِينَ أَنْعَمْتَ عَلَيْهِمْ غَيْرِ ٱلْمَغْضُوبِ عَلَيْهِم وَلاَ ٱلضَّآلِّينَ']

# %%
surah_english[0]
# Out:
# ['In the name of Allah, Most Gracious, Most Merciful.',
#  'Praise be to Allah, the Cherisher and Sustainer of the worlds;',
#  'Most Gracious, Most Merciful;',
#  'Master of the Day of Judgment.',
#  'Thee do we worship, and Thine aid we seek.',
#  'Show us the straight way,',
#  'The way of those on whom Thou hast bestowed Thy Grace, those whose (portion) is not wrath, and who go not astray.']

# %%
tafseer[0]
# Out:
# ['b\'["1 One of the many practices taught by Islam is that its followers should begin their activities in the name of God. This principle, if consciously and earnestly followed, will necessarily yield three beneficial results. First, one will be able to restrain oneself from many misdeed, since the habit of pronouncing the name of God is bound to make one wonder when about to commit some offence how such an act can be reconciled with the saying of God\\x92s holy name. Second, if a man pronounces the name of God before starting good and legitimate tasks, this act will ensue that both his starting point and his mental orientation are sound. Third \\x96 and this is the most important benefit \\x96 when a man begins something by pronouncing God\\x92s name, he will enjoy God\\x92s support and succour; God will bless his efforts and protect him from the machinations and temptation of Satan. For whenever man turns to God, God turns to him as well.\'',
#  "b'2. As we have already explained, the character of this surah is that of a prayer. The prayer begins with praise of the One to whom our prayer is addressed. This indicates that whenever one prays one ought to pray in a dignified manner. It does not become a cultivated person to blurt out his petition. Refinement demands that our requests should be preceded by a wholehearted acknowledgement of the unique position, infinite benevolence and unmatched excellence of the One to Whom we pray. Whenever we praise someone, we do so for two reasons. First, because excellence calls for praise, irrespective of whether that excellence has any direct relevance to us or not. Second, we praise one who, we consider to be our benefactor; when this is the case our praise arises from a deep feeling of gratitude. God is worthy of praise on both counts. It is incumbent on us to praise Him not only in recognition of His infinite excellence but also because of our feeling of gratitude to Him, arising from our awareness of the blessings He has lavished upon us. It is important to note that what is said here is not merely that praise be to God, but that all praise be to God alone. Whenever there is any beauty, any excellence, any perfection-in whatever thing or in whatever shape it may manifest itself- its ultimate source is none other than God Himself. No human beings, angels, Demigods, heavenly bodies-in short, no created beings-are possessed of an innate excellence; where excellence exists, it is a gift from God. Thus, if there is anyone at all whom we ought to adore and worship, to whom we ought to feel indebted and grateful, towards whom we should remain humble and obedient, it is the creator of excellence, rather than its possessor.'",
#  "b'4. Whenever we are deeply impressed by the greatness of something we try to express our feelings by using superlatives. If the use of one superlative does not do full justice to our feelings, we tend to re-emphasize the extraordinary excellence of the object of our admiration by adding a second superlative of nearly equivalent meaning.* This would seem to explain the use of the word Rahim following Rahman. The form of the word Rahman connotes intensity. Yet God\\x92s mercy and beneficence towards His creatures is so great, so extensive and of such an infinite nature that no one word, however strong its connotation, can do it full justice. The epithet Rahim was therefore added to that of Rahman.'",
#  "b'5. God will be the Lord of the Day when all generations of mankind gather together on order to render an account of their conduct, and when each person will be finally rewarded or punished for his deeds. The description of God as Lord of the Day of Judgement following the mention of his benevolence and compassion indicates that we ought to remember another aspect of God as well-namely, that He will judge us all, that He is so absolutely powerful, that on the Day of Judgement no one will have the power either to resist the enforcement of punishments that He decrees or to prevent anyone from receiving the rewards that He decides to confer. Hence, we ought not only to love Him for nourishing and sustaining us and for His compassion and mercy towards us, but should also hold Him in awe because of His justice, and should not forget that our ultimate happiness or misery rests completely with Him.'",
#  "b'6. The term ibadah is used in three sense: (i) worship and adoration; (ii) obedience and submission; and (iii) service and subjection. In this particular context the term carries all these meanings simultaneously. In other words, we say to God that we worship and adore Him, that we are obedient to Him and follow His will, and also that we are His servants. Moreover man is so bound to none save God, that none but He, may be the subject of man\\x92s worship and total devotion, of man\\x92s unreserved obedience, of man\\x92s absolute subjection and servitude.'",
#  "b'8. We beseech God to guide us in all walks of life to a way which is absolutely true, which provides us with a properly-based outlook and sound principles of behaviour, a way which will prevent our succumbing to false doctrines and adopting unsound principles of conduct, a way that will lead us to our true salvation and happiness. This is man\\x92s prayer to God as he begins the study of the Qur\\x92an. It is, in short, to illuminate the truth which he often tends to lose in a labyrinth of philosophical speculation; to enlighten him as to which of the numerous ethical doctrines ensures a sound course of conduct; to show which of the myriad ways and by-ways is the clear, straight, open road of sound belief and right behaviour.'",
#  "b'9. This defines the \\x91straight way\\x92 which we ask God to open to us. It is the way which has always been followed by those who have enjoyed God\\x92s favours and blessings. This is the way which has been trodden from the beginning of time by all those individuals and communities that have unfailingly enjoyed God\\x92s favours and blessings.'"]

# %%
len(tafseer)
# Out:
# 114

# %%
quran = ""
for ayats in surah:
    for ayat in ayats:
        quran += ayat +"\n"

# %%
quran_english = ""
for ayats in surah_english:
    for ayat in ayats:
        quran_english += ayat +"\n"

# %%
len(quran)
# Out:
# 689721

# %%
len(quran_english)
# Out:
# 903077

# %%
tafseer_all = ""
for i in tafseer:
    for j in i:
        tafseer_all += j +"\n"

# %%
len(tafseer_all)
# Out:
# 2571738

# %%
quran.split("\n")[0]
# Out:
# 'بِسمِ ٱلله الرَّحْمٰنِ الرَّحِيـمِ'

# %%
tafseer_all.split("\n")[0]
# Out:
# 'b\'["1 One of the many practices taught by Islam is that its followers should begin their activities in the name of God. This principle, if consciously and earnestly followed, will necessarily yield three beneficial results. First, one will be able to restrain oneself from many misdeed, since the habit of pronouncing the name of God is bound to make one wonder when about to commit some offence how such an act can be reconciled with the saying of God\\x92s holy name. Second, if a man pronounces the name of God before starting good and legitimate tasks, this act will ensue that both his starting point and his mental orientation are sound. Third \\x96 and this is the most important benefit \\x96 when a man begins something by pronouncing God\\x92s name, he will enjoy God\\x92s support and succour; God will bless his efforts and protect him from the machinations and temptation of Satan. For whenever man turns to God, God turns to him as well.\''

# %%
len_of_surahs = []
for i in surah:
    len_of_surahs.append(len(i))

plt.title("Length of Surahs")
plt.plot(len_of_surahs)

# %%
len_of_ayats = []
for i in surah:
    for j in i:
        len_of_ayats.append(len(j))
    
plt.title("Length of Ayats")
plt.plot(len_of_ayats)

# %%
len_of_tafseers = []
for i in tafseer:
    for j in i:
        len_of_tafseers.append(len(j))
    
plt.title("Length of Tafseer")
plt.plot(len_of_tafseers)

# %% [markdown]
# # NLP

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/alizahidraja/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/alizahidraja/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/alizahidraja/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/alizahidraja/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import nltk
import re
import string
from nltk.corpus import stopwords, brown
from nltk.tokenize import word_tokenize, sent_tokenize, RegexpTokenizer
from nltk.stem import WordNetLemmatizer

# %%
lower_case_quran = quran_english.lower()
lower_case_tafseer = tafseer_all.lower()

# %%
def clean_text(lower_case):
    # split text phrases into words
    words  = nltk.word_tokenize(lower_case)
    
    
    # Create a list of all the punctuations we wish to remove
    punctuations = ['.', ',', '/', '!', '?', ';', ':', '(',')', '[',']', '-', '_', '%']
    
    # Remove all the special characters
    punctuations = re.sub(r'\W', ' ', str(lower_case))
    
    stop_words  = stopwords.words('english')
    
    # Getting rid of all the words that contain numbers in them
    w_num = re.sub('\w*\d\w*', '', lower_case).strip()
    
    # remove all single characters
    lower_case = re.sub(r'\s+[a-zA-Z]\s+', ' ', lower_case)
    
    # Substituting multiple spaces with single space
    lower_case = re.sub(r'\s+', ' ', lower_case, flags=re.I)
        
    # Removing non-english characters
    lower_case = re.sub(r'^b\s+', '', lower_case)
    
    # Return keywords which are not in stop words 
    keywords = [word for word in words if not word in stop_words  and word in punctuations and  word in w_num]
    
    return keywords

# %%
# Lemmatize the words
wordnet_lemmatizer = WordNetLemmatizer()

lemmatized_word_quran = [wordnet_lemmatizer.lemmatize(word) for word in clean_text(lower_case_quran)]

clean_data_quran = ' '.join(lemmatized_word_quran)
len(clean_data_quran)
# Out:
# 470616

# %%
# Lemmatize the words
wordnet_lemmatizer = WordNetLemmatizer()

lemmatized_word_tafseer = [wordnet_lemmatizer.lemmatize(word) for word in clean_text(lower_case_tafseer)]

clean_data_tafseer = ' '.join(lemmatized_word_tafseer)
len(clean_data_tafseer)
# Out:
# 1409935

# %%
df_clean_quran = pd.DataFrame([clean_data_quran])
df_clean_quran.columns = ['script']
df_clean_quran.index = ['quran']
df_clean_quran
# Out:
#                                                   script
# quran  name allah gracious merciful praise allah cher...

# %%
df_clean_tafseer = pd.DataFrame([clean_data_tafseer])
df_clean_tafseer.columns = ['script']
df_clean_tafseer.index = ['tafseer']
df_clean_tafseer
# Out:
#                                                     script
# tafseer  b one many practice taught islam follower begi...

# %%
#  Counting the occurrences of tokens and building a sparse matrix of documents x tokens.
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

corpus_quran = df_clean_quran.script
vect_quran = CountVectorizer(stop_words='english')

# Transforms the data into a bag of words
data_vect_quran = vect_quran.fit_transform(corpus_quran)

# %%
corpus_tafseer = df_clean_tafseer.script
vect_tafseer = CountVectorizer(stop_words='english')

# Transforms the data into a bag of words
data_vect_tafseer = vect_tafseer.fit_transform(corpus_tafseer)

# %%
feature_names_quran = vect_quran.get_feature_names()
data_vect_feat_quran = pd.DataFrame(data_vect_quran.toarray(), columns=feature_names_quran)
data_vect_feat_quran.index = df_clean_quran.index
data_vect_feat_quran
# Out:
# /opt/homebrew/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#        aaron  abandon  abandoned  abase  abated  abatement  abhor  abide  \
# quran     24        3          3      1       1          2      1     21
#
#        abides  abiding  ...  youth  youthful  zaid  zakariya  zanjabil  \
# quran       1        2  ...      8         1     1         8         1
#
#        zaqqum  zeal  zihar  zodiacal  zone
# quran       3     2      3         2     2
#
# [1 rows x 5289 columns]

# %%
feature_names_tafseer = vect_tafseer.get_feature_names()
data_vect_feat_tafseer = pd.DataFrame(data_vect_tafseer.toarray(), columns=feature_names_tafseer)
data_vect_feat_tafseer.index = df_clean_tafseer.index
data_vect_feat_tafseer
# Out:
# /opt/homebrew/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#          aa  aabud  aad  aahd  aala  aaraf  aaron  aasin  abaaukum  ababil  \
# tafseer   5      1   31     1     1     10     28      1         1       1
#
#          ...  zoroaster  zoroastrian  zubair  zuhr  zuhri  zukhruf  zuleikha  \
# tafseer  ...          1            1       7     3      5        5         4
#
#          zulm  zumar  zurriyyah
# tafseer     1      2          1
#
# [1 rows x 11978 columns]

# %%
data_quran = data_vect_feat_quran.transpose()
data_quran.shape
# Out:
# (5289, 1)

# %%
data_tafseer = data_vect_feat_tafseer.transpose()
data_tafseer.shape
# Out:
# (11978, 1)

# %%
import matplotlib.pyplot as plt
import seaborn as sn

top_dict_quran = {}
for c in data_quran.columns:
    top = data_quran[c].sort_values(ascending=False)
    top_dict_quran[c]= list(zip(top.index, top.values))
    
top_dict_quran['quran'][:10]
# Out:
# [('allah', 3034),
#  ('ye', 2014),
#  ('lord', 968),
#  ('say', 803),
#  ('thou', 771),
#  ('said', 711),
#  ('shall', 658),
#  ('thee', 612),
#  ('day', 558),
#  ('people', 536)]

# %%
top_dict_tafseer = {}
for c in data_tafseer.columns:
    top = data_tafseer[c].sort_values(ascending=False)
    top_dict_tafseer[c]= list(zip(top.index, top.values))
top_dict_tafseer['tafseer'][:10]
# Out:
# [('verse', 3115),
#  ('commentary', 2259),
#  ('available', 2206),
#  ('abul', 2194),
#  ('maududi', 2186),
#  ('allah', 2119),
#  ('prophet', 2098),
#  ('people', 1880),
#  ('peace', 1795),
#  ('surah', 1634)]

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import nltk


word_count_dict = dict(top_dict_quran['quran'])
popular_words = sorted(word_count_dict, key = word_count_dict.get, reverse = True)
popular_words_nonstop = [w for w in popular_words if w not in stopwords.words("english")]
wordcloud = WordCloud(stopwords=STOPWORDS,
                          background_color='white',
                          max_words=1000,
                          width=1000,height=1000,
                         ).generate(" ".join(popular_words_nonstop))
plt.imshow(wordcloud, interpolation = 'bilinear')
fig=plt.gcf()
fig.set_size_inches(10,12)
plt.axis('off')
plt.title("Top most common 1000 words from Quran",fontsize=20)
plt.tight_layout(pad=0)

# %%
word_count_dict = dict(top_dict_tafseer['tafseer'])
popular_words = sorted(word_count_dict, key = word_count_dict.get, reverse = True)
popular_words_nonstop = [w for w in popular_words if w not in stopwords.words("english")]
wordcloud = WordCloud(stopwords=STOPWORDS,
                          background_color='white',
                          max_words=1000,
                          width=1000,height=1000,
                         ).generate(" ".join(popular_words_nonstop))
plt.imshow(wordcloud, interpolation = 'bilinear')
fig=plt.gcf()
fig.set_size_inches(10,12)
plt.axis('off')
plt.title("Top most common 1000 words from Tafseer",fontsize=20)
plt.tight_layout(pad=0)

# %%
word_count_dict = dict(top_dict_quran['quran'][:50])
popular_words = sorted(word_count_dict, key = word_count_dict.get, reverse = True)
popular_words_nonstop = [w for w in popular_words if w not in stopwords.words("english")]
plt.figure(figsize=(10,10))
plt.barh(range(50), [word_count_dict[w] for w in reversed(popular_words_nonstop[0:50])])
plt.yticks([x + 0.5 for x in range(50)], reversed(popular_words_nonstop[0:50]))
plt.title("Top words")
plt.show()

# %%
word_count_dict = dict(top_dict_tafseer['tafseer'][:50])
popular_words = sorted(word_count_dict, key = word_count_dict.get, reverse = True)
popular_words_nonstop = [w for w in popular_words if w not in stopwords.words("english")]
plt.figure(figsize=(10,10))
plt.barh(range(50), [word_count_dict[w] for w in reversed(popular_words_nonstop[0:50])])
plt.yticks([x + 0.5 for x in range(50)], reversed(popular_words_nonstop[0:50]))
plt.title("Top words")
plt.show()

# %% [markdown]
# # Sentiment Analysis

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/alizahidraja/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sia = SentimentIntensityAnalyzer()
sia.polarity_scores("Islam is the best religion!")
# Out:
# {'neg': 0.0, 'neu': 0.471, 'pos': 0.529, 'compound': 0.6696}

# %%
sia.polarity_scores(quran_english)
# Out:
# {'neg': 0.104, 'neu': 0.765, 'pos': 0.131, 'compound': 1.0}

# %%
sia.polarity_scores(tafseer_all)
# Out:
# {'neg': 0.098, 'neu': 0.786, 'pos': 0.116, 'compound': 1.0}

# %%
s_num = 1
for ayats in surah:
    s = ""
    for ayat in ayats:
        #print(ayat.split("|")[-1])
        s += ayat.split("|")[-1] + "\n"
    print(s_num, sia.polarity_scores(s))
    s_num+=1
# Out:
# 1 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 2 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 3 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 4 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 5 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 6 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 7 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 8 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 9 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 10 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 11 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 12 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 13 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 14 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 15 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 16 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 17 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 18 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 19 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 20 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 21 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 22 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 23 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 24 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 25 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 26 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 27 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 28 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 29 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 30 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 31 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 32 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 33 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 34 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 35 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 36 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 37 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 38 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 39 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 40 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 41 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 42 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 43 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 44 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 45 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 46 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 47 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 48 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 49 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 50 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 51 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 52 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 53 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 54 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 55 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 56 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 57 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 58 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 59 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 60 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 61 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 62 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 63 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 64 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 65 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 66 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 67 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 68 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 69 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 70 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 71 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 72 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 73 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 74 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 75 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 76 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 77 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 78 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 79 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 80 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 81 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 82 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 83 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 84 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 85 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 86 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 87 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 88 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 89 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 90 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 91 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 92 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 93 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 94 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 95 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 96 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 97 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 98 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 99 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 100 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 101 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 102 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 103 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 104 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 105 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 106 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 107 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 108 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 109 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 110 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 111 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 112 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 113 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 114 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
s_num = 1
for ayats in tafseer:
    s = ""
    for ayat in ayats:
        #print(ayat.split("|")[-1])
        s += ayat.split("|")[-1] + "\n"
    print(s_num, sia.polarity_scores(s))
    s_num+=1
# Out:
# 1 {'neg': 0.041, 'neu': 0.708, 'pos': 0.252, 'compound': 0.9998}
# 2 {'neg': 0.086, 'neu': 0.794, 'pos': 0.12, 'compound': 1.0}
# 3 {'neg': 0.098, 'neu': 0.782, 'pos': 0.121, 'compound': 0.9998}
# 4 {'neg': 0.098, 'neu': 0.759, 'pos': 0.144, 'compound': 1.0}
# 5 {'neg': 0.104, 'neu': 0.78, 'pos': 0.117, 'compound': 0.9978}
# 6 {'neg': 0.094, 'neu': 0.782, 'pos': 0.124, 'compound': 0.9999}
# 7 {'neg': 0.109, 'neu': 0.799, 'pos': 0.092, 'compound': -0.9997}
# 8 {'neg': 0.109, 'neu': 0.764, 'pos': 0.128, 'compound': 0.9991}
# 9 {'neg': 0.109, 'neu': 0.756, 'pos': 0.135, 'compound': 0.9999}
# 10 {'neg': 0.099, 'neu': 0.782, 'pos': 0.119, 'compound': 0.9997}
# 11 {'neg': 0.119, 'neu': 0.76, 'pos': 0.121, 'compound': 0.9055}
# 112 {'neg': 0.134, 'neu': 0.787, 'pos': 0.079, 'compound': -0.9963}
# 113 {'neg': 0.09, 'neu': 0.894, 'pos': 0.016, 'compound': -0.961}
# 114 {'neg': 0.135, 'neu': 0.817, 'pos': 0.048, 'compound': -0.9931}

# %% [markdown]
# # TEXT SUMMARY

# %% [markdown]
# ### Summary of Quran

# %%
import heapq

# %%
def summarise(text):
    sentence_list = nltk.sent_tokenize(text)
    stopwords = nltk.corpus.stopwords.words('english')
    word_frequencies = {}
    for word in nltk.word_tokenize(text):
        if word not in stopwords:
            if word not in word_frequencies.keys():
                word_frequencies[word] = 1
            else:
                word_frequencies[word] += 1

    maximum_frequncy = max(word_frequencies.values())
    for word in word_frequencies.keys():
        word_frequencies[word] = (word_frequencies[word]/maximum_frequncy)

    sentence_scores = {}
    for sent in sentence_list:
        for word in nltk.word_tokenize(sent.lower()):
            if word in word_frequencies.keys():
                if len(sent.split(' ')) < 30:
                    if sent not in sentence_scores.keys():
                        sentence_scores[sent] = word_frequencies[word]
                    else:
                        sentence_scores[sent] += word_frequencies[word]


    summary_sentences = heapq.nlargest(7, sentence_scores, key=sentence_scores.get)
    summary = ' '.join(summary_sentences)
    return summary

# %%
summarise(quran_english)
# Out:
# 'O ye who believe! Ah woe, that Day, to the Rejecters of Truth! And verily thy Lord is He, the Exalted in Might, Most Merciful. He said: "Yea, (and more),- for ye shall in that case be (raised to posts) nearest (to my person)." Behold! He said: "O my people! They worked for him as he desired, (making) arches, images, basons as large as reservoirs, and (cooking) cauldrons fixed (in their places): "Work ye, sons of David, with thanks!'

# %% [markdown]
# ### Summary of Surahs

# %%
s_num = 1
for ayats in surah_english:
    s = ""
    for ayat in ayats:
        #print(ayat.split("|")[-1])
        s += ayat.split("|")[-1] + "\n"
    summary = summarise(s)
    if len(summary) < 5:
        print("SURAH NUMBER:",s_num, "SURAH:", s)
    else:
        print("SURAH NUMBER:",s_num, "SUMMARY:", summary)
    print()
    s_num+=1
# Out:
# SURAH NUMBER: 1 SUMMARY: Show us the straight way,
# The way of those on whom Thou hast bestowed Thy Grace, those whose (portion) is not wrath, and who go not astray. Praise be to Allah, the Cherisher and Sustainer of the worlds;
# Most Gracious, Most Merciful;
# Master of the Day of Judgment. In the name of Allah, Most Gracious, Most Merciful. Thee do we worship, and Thine aid we seek.
#
# SURAH NUMBER: 2 SUMMARY: If ye are on a journey, and cannot find a scribe, a pledge with possession (may serve the purpose). Say: "If the last Home, with Allah, be for you specially, and not for anyone else, then seek ye for death, if ye are sincere." They said: "We shall worship Thy god and the god of thy fathers, of Abraham, Isma'il and Isaac,- the one (True) Allah: To Him we bow (in Islam)." And they say: "We hear, and we obey: (We seek) Thy forgiveness, our Lord, and to Thee is the end of all journeys." When ye divorce women, and they fulfil the term of their ('Iddat), do not prevent them from marrying their (former) husbands, if they mutually agree on equitable terms. If ye decide on a foster-mother for your offspring, there is no blame on you, provided ye pay (the mother) what ye offered, on equitable terms. Nay, those who seek gain in evil, and are girt round by their sins,- they are companions of the Fire: Therein shall they abide (For ever).
#
# SURAH NUMBER: 25 SUMMARY: And We have distributed the (water) amongst them, in order that they may celebrate (our) praises, but most men are averse (to aught) but (rank) ingratitude. Thus (is it revealed), that We may strengthen thy heart thereby, and We have rehearsed it to thee in slow, well-arranged stages, gradually. Those who will be gathered to Hell (prone) on their faces,- they will be in an evil plight, and, as to Path, most astray. (Allah will say): "Now have they proved you liars in what ye say: so ye cannot avert (your penalty) nor (get) help." The Day they see the angels,- no joy will there be to the sinners that Day: The (angels) will say: "There is a barrier forbidden (to you) altogether!" Say: "The (Qur'an) was sent down by Him who knows the mystery (that is) in the heavens and the earth: verily He is Oft-Forgiving, Most Merciful." Yet do they worship, besides Allah, things that can neither profit them nor harm them: and the Misbeliever is a helper (of Evil), against his own Lord!
#
# SURAH NUMBER: 26 SUMMARY: And verily thy Lord is He, the Exalted in Might, Most Merciful. Then Pharaoh sent heralds to (all) the Cities,
# (Saying): "These (Israelites) are but a small band,
# "And they are raging furiously against us;
# "But we are a multitude amply fore-warned." He said: "Yea, (and more),- for ye shall in that case be (raised to posts) nearest (to my person)." "'Now, then, we have none to intercede (for us),
# "'Nor a single friend to feel (for us). "Will ye be left secure, in (the enjoyment of) all that ye have here?-
# "Gardens and Springs,
# "And corn-fields and date-palms with spathes near breaking (with the weight of fruit)? "But fear Allah and obey me;
# "And follow not the bidding of those who are extravagant,-
# "Who make mischief in the land, and mend not (their ways)." Verily in this is a Sign: but most of them do not believe.
#
# SURAH NUMBER: 27 SUMMARY: "Go thou, with this letter of mine, and deliver it to them: then draw back from them, and (wait to) see what answer they return"...
# (The queen) said: "Ye chiefs! We sent (aforetime), to the Thamud, their brother Salih, saying, "Serve Allah": But behold, they became two factions quarrelling with each other. (We also sent) Lut (as a messenger): behold, He said to his people, "Do ye do what is shameful though ye see (its iniquity)? Or, Who listens to the (soul) distressed when it calls on Him, and Who relieves its suffering, and makes you (mankind) inheritors of the earth? I have indeed wronged my soul: I do (now) submit (in Islam), with Solomon, to the Lord of the Worlds." "But I am going to send him a present, and (wait) to see with what (answer) return (my) ambassadors." But when he came to the (fire), a voice was heard: "Blessed are those in the fire and those around: and glory to Allah, the Lord of the worlds.
#
# SURAH NUMBER: 28 SUMMARY: But (now), when the Truth has come to them from Ourselves, they say, "Why are not (Signs) sent to him, like those which were sent to Moses?" Did he not know that Allah had destroyed, before him, (whole) generations,- which were superior to him in strength and greater in the amount (of riches) they had collected? "Move thy hand into thy bosom, and it will come forth white without stain (or harm), and draw thy hand close to thy side (to guard) against fear. Then, when he turned his face towards (the land of) Madyan, he said: "I do hope that my Lord will show me the smooth and straight Path." The reward of Allah (in the Hereafter) is best for those who believe and work righteousness: but this none shall attain, save those who steadfastly persevere (in good)." They said: "We cannot water (our flocks) until the shepherds take back (their flocks): And our father is a very old man." So when he came to him and narrated the story, he said: "Fear thou not: (well) hast thou escaped from unjust people."
#
#
# SURAH NUMBER: 34 SUMMARY: They worked for him as he desired, (making) arches, images, basons as large as reservoirs, and (cooking) cauldrons fixed (in their places): "Work ye, sons of David, with thanks! Say: "Verily my Lord doth cast the (mantle of) Truth (over His servants),- He that has full knowledge of (all) that is hidden." We have not sent thee but as a universal (Messenger) to men, giving them glad tidings, and warning them (against sin), but most men understand not. "- Nay, it is those who believe not in the Hereafter, that are in (real) Penalty, and in farthest error. Say: "No reward do I ask of you: it is (all) in your interest: my reward is only due from Allah: And He is witness to all things." When Our Clear Signs are rehearsed to them, they say, "This is only a man who wishes to hinder you from the (worship) which your fathers practised." "Eat of the Sustenance (provided) by your Lord, and be grateful to Him: a territory fair and happy, and a Lord Oft-Forgiving!
#
# SURAH NUMBER: 35 SUMMARY: Nor are the two bodies of flowing water alike,- the one palatable, sweet, and pleasant to drink, and the other, salt and bitter. Is he, then, to whom the evil of his conduct is made alluring, so that he looks upon it as good, (equal to one who is rightly guided)? If ye invoke them, they will not listen to your call, and if they were to listen, they cannot answer your (prayer). And if they reject thee, so did their predecessors, to whom came their messengers with Clear Signs, Books of dark prophecies, and the Book of Enlightenment. For those who reject Allah, is a terrible Penalty: but for those who believe and work righteous deeds, is Forgiveness, and a magnificent Reward. Or have We given them a Book from which they (can derive) clear (evidence)?- Nay, the wrong-doers promise each other nothing but delusions. Those truly fear Allah, among His Servants, who have knowledge: for Allah is Exalted in Might, Oft-Forgiving.
#
# SURAH NUMBER: 36 SUMMARY: And he makes comparisons for Us, and forgets his own (origin and) Creation: He says, "Who can give life to (dry) bones and decomposed ones (at that)?" "Embrace ye the (fire) this Day, for that ye (persistently) rejected (Truth)." No (chance) will they then have, by will, to dispose (of their affairs), nor to return to their own people! of them some do carry them and some they eat:
# And they have (other) profits from them (besides), and they get (milk) to drink. When they are told, "Fear ye that which is before you and that which will be after you, in order that ye may receive Mercy," (they turn back). "For me, I have faith in the Lord of you (all): listen, then, to me!" Glory to Allah, Who created in pairs all things that the earth produces, as well as their own (human) kind and (other) things of which they have no knowledge.
#
# SURAH NUMBER: 37 SUMMARY: Then, when (the son) reached (the age of) (serious) work with him, he said: "O my son! "Bring ye up", it shall be said, "The wrong-doers and their wives, and the things they worshipped-
# "Besides Allah, and lead them to the Way to the (Fierce) Fire! For, verily, neither ye nor those ye worship-
# Can lead (any) into temptation concerning Allah,
# Except such as are (themselves) going to the blazing Fire! Already has Our Word been passed before (this) to our Servants sent (by Us),
# That they would certainly be assisted,
# And that Our forces,- they surely must conquer. (A voice will say,) "This is the Day of Sorting Out, whose truth ye (once) denied!" he has come with the (very) Truth, and he confirms (the Message of) the messengers (before him). when we die, and become dust and bones, shall we (then) be raised up (again)
# "And also our fathers of old?"
#
# SURAH NUMBER: 38 SUMMARY: (Iblis) said: "Then, by Thy power, I will put them all in the wrong,-
# "Except Thy Servants amongst them, sincere and purified (by Thy Grace)." but - for the wrong-doers will be an evil place of (Final) Return!-
#
# SURAH NUMBER: 84 SUMMARY: What then is the matter with them, that they believe not?-
# And when the Qur'an is read to them, they fall not prostrate,
# But on the contrary the Unbelievers reject (it). Then he who is given his Record in his right hand,
# Soon will his account be taken by an easy reckoning,
# And he will turn to his people, rejoicing! But he who is given his Record behind his back,-
# Soon will he cry for perdition,
# And he will enter a Blazing Fire. Truly, did he go about among his people, rejoicing! Verily thou art ever toiling on towards thy Lord- painfully toiling,- but thou shalt meet Him. Truly, did he think that he would not have to return (to Us)! for his Lord was (ever) watchful of him!
#
# SURAH NUMBER: 85 SUMMARY: And He is the Oft-Forgiving, Full of Loving-Kindness,
# Lord of the Throne of Glory,
# Doer (without let) of all that He intends. they sat over against the (fire),
# And they witnessed (all) that they were doing against the Believers. Nay, this is a Glorious Qur'an,
# (Inscribed) in a Tablet Preserved! And yet the Unbelievers (persist) in rejecting (the Truth)! It is He Who creates from the very beginning, and He can restore (life). Has the story reached thee, of the forces-
# Of Pharaoh and the Thamud? But Allah doth encompass them from behind!
#
# SURAH NUMBER: 86 SUMMARY: The Day that (all) things secret will be tested,
# (Man) will have no power, and no helper. He is created from a drop emitted-
# Proceeding from between the backbone and the ribs:
# Surely (Allah) is able to bring him back (to life)! Therefore grant a delay to the Unbelievers: Give respite to them gently (for awhile). As for them, they are but plotting a scheme,
# And I am planning a scheme. Now let man but think from what he is created!
#
# SURAH NUMBER: 87 SUMMARY: And granted guidance;
# And Who bringeth out the (green and luscious) pasture,
# And then doth make it (but) swarthy stubble. By degrees shall We teach thee to declare (the Message), so thou shalt not forget,
# Except as Allah wills: For He knoweth what is manifest and what is hidden. Glorify the name of thy Guardian-Lord Most High,
# Who hath created, and further, given order and proportion;
# Who hath ordained laws. But those will prosper who purify themselves,
# And glorify the name of their Guardian-Lord, and (lift their hearts) in prayer. And We will make it easy for thee (to follow) the simple (Path). Nay (behold), ye prefer the life of this world;
# But the Hereafter is better and more enduring. And this is in the Books of the earliest (Revelation),-
# The Books of Abraham and Moses.
#
# SURAH NUMBER: 88 SUMMARY: Therefore do thou give admonition, for thou art one to admonish. Thou art not one to manage (men's) affairs. Has the story reached thee of the overwhelming (Event)?
#
# SURAH NUMBER: 89 SUMMARY: Now, as for man, when his Lord trieth him, giving him honour and gifts, then saith he, (puffed up), "My Lord hath honoured me." Seest thou not how thy Lord dealt with the 'Ad (people),-
# Of the (city of) Iram, with lofty pillars,
# The like of which were not produced in (all) the land? (To the righteous soul will be said:) "O (thou) soul, in (complete) rest and satisfaction! For, that Day, His Chastisement will be such as none (else) can inflict,
# And His bonds will be such as none (other) can bind. And with the Thamud (people), who cut out (huge) rocks in the valley?-
# And with Pharaoh, lord of stakes? But when He trieth him, restricting his subsistence for him, then saith he (in despair), "My Lord hath humiliated me!" Would that I had sent forth (good deeds) for (this) my (Future) Life!"
#
# SURAH NUMBER: 90 SUMMARY: I do call to witness this City;-
# And thou art a freeman of this City;-
# And (the mystic ties of) parent and child;-
#
# SURAH NUMBER: 99 SUMMARY: When the earth is shaken to her (utmost) convulsion,
# And the earth throws up her burdens (from within),
# And man cries (distressed): 'What is the matter with her? On that Day will men proceed in companies sorted out, to be shown the deeds that they (had done). And anyone who has done an atom's weight of evil, shall see it. Then shall anyone who has done an atom's weight of good, see it! '-
# On that Day will she declare her tidings:
# For that thy Lord will have given her inspiration.
#
# SURAH NUMBER: 100 SURAH: By the (Steeds) that run, with panting (breath),
# And strike sparks of fire,
# And push home the charge in the morning,
# And raise the dust in clouds the while,
# And penetrate forthwith into the midst (of the foe) en masse;-
# Truly man is, to his Lord, ungrateful;
# And to that (fact) he bears witness (by his deeds);
# And violent is he in his love of wealth.
# Does he not know,- when that which is in the graves is scattered abroad
# And that which is (locked up) in (human) breasts is made manifest-
# That their Lord had been Well-acquainted with them, (even to) that Day?
#
#
# SURAH NUMBER: 101 SUMMARY: But he whose balance (of good deeds) will be (found) light,-
# Will have his home in a (bottomless) Pit. Then, he whose balance (of good deeds) will be (found) heavy,
# Will be in a life of good pleasure and satisfaction. The (Day) of Noise and Clamour:
# What is the (Day) of Noise and Clamour? (It is) a Day whereon men will be like moths scattered about,
# And the mountains will be like carded wool. And what will explain to thee what the (Day) of Noise and Clamour is? (It is) a Fire Blazing fiercely! And what will explain to thee what this is?
#
# SURAH NUMBER: 102 SUMMARY: Nay, were ye to know with certainty of mind, (ye would beware!) The mutual rivalry for piling up (the good things of this world) diverts you (from the more serious things),
# Until ye visit the graves. Then, shall ye be questioned that Day about the joy (ye indulged in! But nay, ye soon shall know (the reality). Again, ye soon shall know! Again, ye shall see it with certainty of sight! Ye shall certainly see Hell-Fire!
#
# SURAH NUMBER: 103 SURAH: By (the Token of) Time (through the ages),
# Verily Man is in loss,
# Except such as have Faith, and do righteous deeds, and (join together) in the mutual teaching of Truth, and of Patience and Constancy.
#
#
# SURAH NUMBER: 104 SUMMARY: Woe to every (kind of) scandal-monger and-backbiter,
# Who pileth up wealth and layeth it by,
# Thinking that his wealth would make him last for ever! He will be sure to be thrown into That which Breaks to Pieces,
# And what will explain to thee That which Breaks to Pieces? By no means!
#
# SURAH NUMBER: 105 SUMMARY: Then did He make them like an empty field of stalks and straw, (of which the corn) has been eaten up. Did He not make their treacherous plan go astray? And He sent against them Flights of Birds,
# Striking them with stones of baked clay. Seest thou not how thy Lord dealt with the Companions of the Elephant?
#
# SURAH NUMBER: 106 SURAH: For the covenants (of security and safeguard enjoyed) by the Quraish,
# Their covenants (covering) journeys by winter and summer,-
# Let them adore the Lord of this House,
# Who provides them with food against hunger, and with security against fear (of danger).
#
#
# SURAH NUMBER: 107 SUMMARY: So woe to the worshippers
# Who are neglectful of their prayers,
# Those who (want but) to be seen (of men),
# But refuse (to supply) (even) neighbourly needs. Then such is the (man) who repulses the orphan (with harshness),
# And encourages not the feeding of the indigent. Seest thou one who denies the Judgment (to come)?
#
# SURAH NUMBER: 108 SUMMARY: For he who hateth thee, he will be cut off (from Future Hope). To thee have We granted the Fount (of Abundance). Therefore to thy Lord turn in Prayer and Sacrifice.
#
# SURAH NUMBER: 109 SUMMARY: And I will not worship that which ye have been wont to worship,
# Nor will ye worship that which I worship. I worship not that which ye worship,
# Nor will ye worship that which I worship. Say: O ye that reject Faith! To you be your Way, and to me mine.
#
# SURAH NUMBER: 110 SURAH: When comes the Help of Allah, and Victory,
# And thou dost see the people enter Allah's Religion in crowds,
# Celebrate the praises of thy Lord, and pray for His Forgiveness: For He is Oft-Returning (in Grace and Mercy).
#
#
# SURAH NUMBER: 111 SUMMARY: His wife shall carry the (crackling) wood - As fuel!-
# A twisted rope of palm-leaf fibre round her (own) neck! No profit to him from all his wealth, and all his gains! Perish the hands of the Father of Flame! Burnt soon will he be in a Fire of Blazing Flame! Perish he!
#
# SURAH NUMBER: 112 SUMMARY: Say: He is Allah, the One and Only;
# Allah, the Eternal, Absolute;
# He begetteth not, nor is He begotten;
# And there is none like unto Him.
#
# SURAH NUMBER: 113 SURAH: Say: I seek refuge with the Lord of the Dawn
# From the mischief of created things;
# From the mischief of Darkness as it overspreads;
# From the mischief of those who practise secret arts;
# And from the mischief of the envious one as he practises envy.
#
#
# SURAH NUMBER: 114 SURAH: Say: I seek refuge with the Lord and Cherisher of Mankind,
# The King (or Ruler) of Mankind,
# The god (or judge) of Mankind,-
# From the mischief of the Whisperer (of Evil), who withdraws (after his whisper),-
# (The same) who whispers into the hearts of Mankind,-
# Among Jinns and among men.

# %% [markdown]
# ### Summary of Tafaseer

# %%
s_num = 1
for ayats in tafseer:
    s = ""
    for ayat in ayats:
        #print(ayat.split("|")[-1])
        s += ayat.split("|")[-1] + "\n"
    summary = summarise(s)
    if len(summary) < 5:
        print("SURAH NUMBER:",s_num, "TAFSEER:", s)
    else:
        print("SURAH NUMBER:",s_num, "TAFSEER SUMMARY:", summary)
    print()
    s_num+=1
# Out:
# SURAH NUMBER: 1 TAFSEER SUMMARY: No human beings, angels, Demigods, heavenly bodies-in short, no created beings-are possessed of an innate excellence; where excellence exists, it is a gift from God. Second, we praise one who, we consider to be our benefactor; when this is the case our praise arises from a deep feeling of gratitude. First, because excellence calls for praise, irrespective of whether that excellence has any direct relevance to us or not. Whenever there is any beauty, any excellence, any perfection-in whatever thing or in whatever shape it may manifest itself- its ultimate source is none other than God Himself. This principle, if consciously and earnestly followed, will necessarily yield three beneficial results. Refinement demands that our requests should be preceded by a wholehearted acknowledgement of the unique position, infinite benevolence and unmatched excellence of the One to Whom we pray. For whenever man turns to God, God turns to him as well.'
#
# SURAH NUMBER: 2 TAFSEER SUMMARY: b'There is no commentary by Abul Maududi available for this verse.' 205 and 209: Darimi, \x91 Sawm\x92, 41; Muslim, \x91Siyarn\x92, 92; Nasai, Siyam\x92, 47; Bukhari, \x91Maghazi\x92, 71; Muslim, \x91Siyam\x92, 102; Ahmad b. Hanbal, Musnad, vol. (See Bukhari, \x91Tafsir al-Qur\x92an\x92, 25; Tirmidhi, Sawm\x92, 21; Nasai, \x91Siyam\x92, 51, 62, 64; Ibn Majah, \x91Siyam\x92, 12; Ahmad b. H
# SURAH NUMBER: 97 TAFSEER SUMMARY: 19 of Surah Al-Aaraf);(E.Ns 108, 109 of Surah Younus), (E.Ns 43 to 47 of Surah Ar-Room); (E.Ns 3, 4 of Surah Az-Zumar). Likewise,alladhina kafaru min ahl-il-Kitabi wal-mushrikin means: thedisbelievers from among the followers of the Book and themushriks, and not, those who have disbelieved from thesetwo groups.' Therefore, they themselveswere responsible for their deviation, for Allah had fulfilledHis obligation towards them. Here the word kufr (unbelief) has been used in its widestsense, which includes different forms of the unbelievingattitude. (For further explanation, see(E.N. Inshort, there were different kinds of kufr in which the peoplewere involved. This has been stated at many places in theQuran, e.g.
#
# SURAH NUMBER: 98 TAFSEER SUMMARY: (Musnad Ahmad, Tirmidhi, Nasai, Ibn Jarir, Abd bin Humaid, Ibn al-Mundhir, Hakim, Ibn Marduyah, Baihaqi in Ash-Shuab). This same has been expressed in Surah Al-Inshiqaq, Ayat 4, thus: And throws out whatever is within it, and becomes empty. But, according to a large section of them, it implies the earthquake with which the second stage of Resurrection will begin, i.e. Then, in order to express the great intensity of the earthquake the word zilzalaha has been added, which literally means: its being shaken. The probability, however, is that the believers will give them this answer.' As for the believers, they will not be bewildered and confused, for everything would be taking place according to their belief and conviction. It means: It will be so shaken as a huge sphere like it ought to be shaken, or shaken to its utmost intensity.
#
# SURAH NUMBER: 99 TAFSEER SUMMARY: Strike sparks: indicates that the horses run in the dead of night, for the sparks struck by their hoofs become conspicuous only at night.' b'There is no commentary by Abul Maududi available for this verse.' Both these meanings are opposed not only to the explanations given in the Quran and the Hadith, but also to reason. This can have two meanings:'
# b'There is no commentary by Abul Maududi available for this verse.' One section of the companions and their immediate successors has been to think that it implies the horses; another section says that it implies the camels. b'5. b'7.
#
# SURAH NUMBER: 100 TAFSEER SUMMARY: b'There is no commentary by Abul Maududi available for this verse.' In ( Surah Al-Baqarah, Ayat 180), khair has been used in the meaning of worldly wealth. That is, He will be knowing well who is who, and what punishment or reward he deserves.' That is, the dead men will be raised back as living men from whatever state and wherever they would be lying buried in the earth.' Thus, the use of tahsil concerning hidden secrets of the hearts contains both the meanings: to expose them and to sort out the good from the evil. Tahsil means to bring out something in the open, and to sort out different things from one another. If man only considers this, he cannot help admitting that real and complete justice cannot be done anywhere except in the court of God.
#
# SURAH NUMBER: 101 TAFSEER SUMMARY: b'There is no commentary by Abul Maududi available for this verse.' In the first case, mawazin would imply the deeds which might have some weight in the sight of Allah and be, thus, worthy of appreciation. Besides, in Arabic idiom the word mizan is also used for weight (wazan); accordingly, the weight\x92s being heavy or light implies the good deeds being heavy or light. That is, you spend your whole life in the same craze and endeavor, until the time comes when you must die and leave the world.' b'3. Hawiyah is from hawa, which means to fall from a height to a depth, and hawiyah is the deep pit into which something falls. That is, it will not merely be a deep pit but will also be full of raging fire.'
#
# SURAH NUMBER: 102 TAFSEER SUMMARY: b'There is no commentary by Abul Maududi available for this verse.' But this differenceis not definite and clear, for the meaning given to hamz bysome Arabic speaking people themselves is given to lamz byother Arabic speaking peoples. On the contrary, themeaning given to lamz by some people is given to hamz byothers. The words jama a malan for collectingmoney suggest the abundance of wealth; then the wordscounting it over and over again depict the person\x92smiserliness and his selfish hoarding of wealth.' This second sentence after the first sentence by itselfgives the meaning that he slanders others because of hispride of wealth. b'1. b'4.
#
# SURAH NUMBER: 103 TAFSEER SUMMARY: b'3. Another meaning also can be: He thinks that his wealthwill make him immortal. b'4. Nabdh inArabic is used for throwing away a thing regarding it asworthless and mean. b'There is no commentary by Abul Maududi available for this verse.' The word in the original is la yunbadhanna.
#
# SURAH NUMBER: 104 TAFSEER SUMMARY: That is, after the culprits have been thrown into it, Hellwill be closed in upon them without leaving any slit oropening anywhere, in order to choke and suffocate them.' According to Ibn Abbas\x92s tradition that Abu Nuaim has related, they were equal to a pine kernel, and according to Ibn Marduyah, equal to a goat\x92s dropping. Tattaliu is from ittalaa, which means to climb and mountto the top, and also to be aware and informed. b'6. b'7. Obviously, all the stones might not be equal but differing in size to some extent.' Ibn Abbas says that sijjil is the Arabic version of the Persian sang and gil, and it implies the stones made from clay and become hard when baked.
#
# SURAH NUMBER: 105 TAFSEER SUMMARY: Therefore, whatever they have achieved, it has been possible only by the help of the Lord of this House; therefore, they should worship Him alone.' They themselves acknowledge that the 360 idols, which they worship, are not its lord, but Allah alone is its Lord. In summer the Quraish travelled northward to Syria and Palestine, for they are cool lands, and in winter southward to Yaman, etc. If the word araaita is taken in the second meaning, the verse would mean: Do you know the kind of man who belies the rewards and punishments. b'1. (Surah Ibrahim, Ayat 37).' About the lam that is prefixed to ilaf, some Arabists have expressed the opinion that it is to express surprise and wonder.
#
# SURAH NUMBER: 106 TAFSEER SUMMARY: Or, when they rise up for the Prayer, they rise up and perform it with an unwilling heart, as if it were a calamity imposed on them. That is, we do forget in the course of the Prayer but we are not forgetful and neglectful of it; therefore, we shall not be counted among the hypocrites.' Since, despite being Muslims they regard the Hereafter as a falsehood, one may note what path of ruin they are following.' Whether they perform the Prayer, or do not perform it, it is of little importance to them. When they perform it, they do not observe the prescribed times, but offer it carelessly at the eleventh hour. Or, it gives the meaning: Because of his this very denial of the Hereafter he is the kind of man who drives away the orphan.' In case the words fi salat-i him had been used, the meaning would be that they forget in the course of their Prayer.
#
# SURAH NUMBER: 107 TAFSEER SUMMARY: (Ibn Jarir, Ibn Abi Shaibah, Abu Daud, Nasai, Bazzar, Ibn al-Mundhir, Ibn Abi Hatim, Tabarani in Al- Ausat, Ibn Marduyah, Baihaqi in As-Sunan). Ata, Mujahid, Ikrimah, Hasan Basri, Qatadah, Muhammad bin Kaab al-Qurzi, Dahhak, Rabi bin Anas, Ata al-Khurasani and many other major commentators. (Ibn Jarir, Ibn al-Mundhir, Ibn Abi Hatim , Ibn Marduyah, Baihaqi , in Ash-Shuab). The full meaning of the word kauthar, as used here, cannot perhaps be expressed in one word in any language of the world. The word shani as used, in the original is derived from shaan, which means the hatred and spite because of which a person may start ill-treating another. Ibn Abi Hatim has related from Ikrimah that maun of the highest form is zakat and of the lowest lending of a sieve, bucket, or needle to a borrower. How then can it be correct to exonerate oneself from the worship of all the deities of all those people, without exception, when Allah too is included among them?'
#
# SURAH NUMBER: 108 TAFSEER SUMMARY: But after negating the repetition the meanings that this section of the commentators has given of these two sentences are very different from each other. The commentators generally give four answers to it:'
# SURAH NUMBER: 114 TAFSEER SUMMARY: In (Surah Al-Qasas, Ayat 29), the word anasa has been used in the meaning of raa, i.e. In (Surah An-Nisa, Ayat 6), the word anastum has been used in the meaning of ahsastum or raaytum (i.e. But this view is wrong because the words naas, ins and insan are even lexically contrary in meaning to the word jinn. According to some scholars, these words mean that the whisperer whispers evil into the hearts of two kinds of people: the jinn and the men. If this meaning is admitted, the word naas would apply to both jinn and men. On the contrary, the words naas and ins are spoken for insan (man) only on the basis that he is manifest and visible and perceptible. The actual meaning of jinn is hidden creation and jinn is called jinn because he is hidden from man\x92s eye.

# %% [markdown]
# # Search Engine

# %%
import tensorflow as tf
import tensorflow_hub as hub
from tqdm import tqdm
from nltk.corpus import wordnet as wn
from nltk import pos_tag
from nltk.corpus import stopwords
from sklearn.metrics.pairwise import linear_kernel
import collections

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/alizahidraja/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
df['useful_info'] = df.EnglishTranslation.astype(str) + df.Tafseer.astype(str) 

df["useful_info"] = df.useful_info.replace(to_replace='[!"#$%&\'()*+,/:;<=>?@[\\]^_`{|}~]',value=' ',regex=True) 
#remove punctuation
df.useful_info =df.useful_info.replace(to_replace='-',value=' ',regex=True)
df.useful_info =df.useful_info.replace(to_replace='\s+',value=' ',regex=True)    #remove new line
df.useful_info =df.useful_info.replace(to_replace='  ',value='',regex=True)   #remove double white space  
df.useful_info =df.useful_info.replace(to_replace="'",value='',regex=True)   


df.useful_info = df.useful_info.apply(lambda x:x.strip().lower())  # Ltrim and Rtrim of whitespace

# %%
df["info_tokenize"]= [word_tokenize(entry) for entry in tqdm(df["useful_info"])]
# Out:
# 100%|██████████| 6236/6236 [00:01<00:00, 4193.45it/s]

# %%
def wordLemmatizer(data):
    tag_map = collections.defaultdict(lambda : wn.NOUN)
    tag_map['J'] = wn.ADJ
    tag_map['V'] = wn.VERB
    tag_map['R'] = wn.ADV
    clean_k =pd.DataFrame()
    word_Lemmatized = WordNetLemmatizer()
    for index,entry in tqdm(enumerate(data)):
        
        Final_words = []
        for word, tag in pos_tag(entry):
            if len(word)>1 and word not in stopwords.words('english') and word.isalpha():
                word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
                Final_words.append(word_Final)
        
        clean_k.loc[index,'Keyword_final'] = str(Final_words)
    clean_k=clean_k.replace(to_replace ="'", value = '', regex = True)
    clean_k=clean_k.replace(to_replace =" ", value = '', regex = True)
    clean_k=clean_k.replace(to_replace ="\[", value = '', regex = True)
    clean_k=clean_k.replace(to_replace ='\]', value = '', regex = True)
    return clean_k

# %%
df["Keyword_final"] = wordLemmatizer(df['info_tokenize'])
df.head()
# Out:
# 6236it [00:45, 136.19it/s]
#           Name  Surah  Ayat                                    Arabic  \
# 0  The Opening      1     1        بِسمِ ٱلله الرَّحْمٰنِ الرَّحِيـمِ
# 1  The Opening      1     2      ٱلْحَمْدُ للَّهِ رَبِّ ٱلْعَالَمِينَ
# 2  The Opening      1     3                   ٱلرَّحْمـٰنِ ٱلرَّحِيمِ
# 3  The Opening      1     4                  مَـٰلِكِ يَوْمِ ٱلدِّينِ
# 4  The Opening      1     5  إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ
#
#                                   EnglishTranslation  \
# 0  In the name of Allah, Most Gracious, Most Merc...
# 1  Praise be to Allah, the Cherisher and Sustaine...
# 2                      Most Gracious, Most Merciful;
# 3                     Master of the Day of Judgment.
# 4         Thee do we worship, and Thine aid we seek.
#
#                                              Tafseer  \
# 0  b'["1 One of the many practices taught by Isla...
# 1  b'2. As we have already explained, the charact...
# 2  b'4. Whenever we are deeply impressed by the g...
# 3  b'5. God will be the Lord of the Day when all ...
# 4  b'6. The term ibadah is used in three sense: (...
#
#                                          useful_info  \
# 0  in the name of allah most gracious most mercif...
# 1  praise be to allah the cherisher and sustainer...
# 2  most gracious most merciful b 4. whenever we a...
# 3  master of the day of judgment.b 5. god will be...
# 4  thee do we worship and thine aid we seek.b 6. ...
#
#                                        info_tokenize  \
# 0  [in, the, name, of, allah, most, gracious, mos...
# 1  [praise, be, to, allah, the, cherisher, and, s...
# 2  [most, gracious, most, merciful, b, 4., whenev...
# 3  [master, of, the, day, of, judgment.b, 5., god...
# 4  [thee, do, we, worship, and, thine, aid, we, s...
#
#                                        Keyword_final
# 0  name,allah,gracious,one,many,practice,teach,is...
# 1  praise,allah,cherisher,sustainer,world,already...
# 2  gracious,merciful,whenever,deeply,impress,grea...
# 3  master,day,god,lord,day,generation,mankind,gat...
# 4  thee,worship,thine,aid,term,ibadah,use,three,s...

# %%
#Using Google Universal Sentence Encoder
#USEmodel = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")
### NEED TO DOWNLOAD THE MODEL
USEmodel = hub.load("model/universal-sentence-encoder_4/")
# Out:
# 2023-01-08 18:47:26.835070: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz

# %%
train = USEmodel(df.Keyword_final)
train_m = tf.train.Checkpoint(v=tf.Variable(train))

train_m.f = tf.function( lambda  x: exported_m.v * x, input_signature=[tf.TensorSpec(shape=None, dtype=tf.float32)])

model = train_m.v.numpy()

# %%
model.shape
# Out:
# (6236, 512)

# %%
def SearchDocument(query,size=10):
    
    q = wordLemmatizer([query.split(" ")])
    #print(q.values[0])
    Q_Train = USEmodel(q.values[0])
    
    linear_similarities = linear_kernel(Q_Train, model).flatten() 
    
    Top_index_doc = linear_similarities.argsort()[:-(size+1):-1]
    #print(Top_index_doc)
    linear_similarities.sort()
    find = pd.DataFrame()
    for i,index in enumerate(Top_index_doc):
        find.loc[i,'Name'] = str(df['Name'][index])
        find.loc[i,'Surah'] = str(df['Surah'][index])
        find.loc[i,'Ayat'] = str(df['Ayat'][index])
        find.loc[i,'Arabic'] = df['Arabic'][index]
        find.loc[i,'EnglishTranslation'] = df['EnglishTranslation'][index] 
        find.loc[i,'Tafseer'] = df['Tafseer'][index]
        
        
    for j,simScore in enumerate(linear_similarities[:-(size+1):-1]):
        find.loc[j,'Score'] = simScore
        
    if size==1:
        print("Query: ",query,".  Surah:", find.loc[0,'Name'], " Number:", find.loc[0,'Surah'], 
              " Ayat:", find.loc[0,'Ayat']," Tafseer: ", find.loc[0,'Tafseer'], "\n")
    else:
        return find

# %%
SearchDocument("Happiness")
# Out:
# 1it [00:00, 283.36it/s]
#                           Name Surah Ayat  \
# 0                         Mary    19   27
# 1                        Tâ Hâ    20   16
# 2  Rivalry in Worldly Increase   102    1
# 3                The Believers    23    9
# 4                     The Star    53   15
# 5                        Women     4   84
# 6                    The Story    28   53
# 7                      The Cow     2  173
# 8                      Banning    66   12
# 9         Those Who Drag Forth    79   37
#
#                                               Arabic  \
# 0  فَأَتَتْ بِهِ قَوْمَهَا تَحْمِلُهُ قَالُواْ يٰ...
# 1  فَلاَ يَصُدَّنَّكَ عَنْهَا مَن لاَّ يُؤْمِنُ ب...
# 2                          أَلْهَاكُمُ ٱلتَّكَّاثُرُ
# 3  وَٱلَّذِينَ هُمْ عَلَىٰ صَلَوَاتِهِمْ يُحَافِظ...
# 4                       عِندَهَا جَنَّةُ ٱلْمَأْوَىٰ
# 5  فَقَاتِلْ فِي سَبِيلِ ٱللَّهِ لاَ تُكَلَّفُ إِ...
# 6  وَإِذَا يُتْلَىٰ عَلَيْهِمْ قَالُوۤاْ آمَنَّا ...
# 7  إِنَّمَا حَرَّمَ عَلَيْكُمُ ٱلْمَيْتَةَ وَٱلدّ...
# 8  وَمَرْيَمَ ٱبْنَتَ عِمْرَانَ ٱلَّتِيۤ أَحْصَنَ...
# 9                                فَأَمَّا مَن طَغَىٰ
#
#                                   EnglishTranslation  \
# 0  At length she brought the (babe) to her people...
# 1  "Therefore let not such as believe not therein...
# 2  The mutual rivalry for piling up (the good thi...
# 3           And who (strictly) guard their prayers;-
# 4                    Near it is the Garden of Abode.
# 5  Then fight in Allah's cause - Thou art held re...
# 6  And when it is recited to them, they say: "We ...
# 7  He hath only forbidden you dead meat, and bloo...
# 8  And Mary the daughter of 'Imran, who guarded h...
# 9     Then, for such as had transgressed all bounds,
#
#                                              Tafseer     Score
# 0  b'There is no commentary by Abul Maududi avail...  0.455811
# 1  b'There is no commentary by Abul Maududi avail...  0.413493
# 2  b'There is no commentary by Abul Maududi avail...  0.410682
# 3  b'9. Salawat is plural of Salat. In( verse 2) ...  0.403948
# 4  b'There is no commentary by Abul Maududi avail...  0.397828
# 5  b'There is no commentary by Abul Maududi avail...  0.393023
# 6  b'73. That is, \x93Even before this we were be...  0.389848
# 7  b'171. This applies to the flesh of an animal ...  0.383862
# 8  b'9. The world\x92s heaven: the heaven the sta...  0.383181
# 9  b'22. The disbelievers of Makkah asked this qu...  0.383122

# %%
SearchDocument("What reward do I get?")
# Out:
# 1it [00:00, 110.32it/s]
#                               Name Surah Ayat  \
# 0                       Repentance     9   55
# 1  Fussilat ("They are Expounded")    41   48
# 2                        Crouching    45   30
# 3                            Smoke    44   27
# 4                  The Cloaked One    74   39
# 5                              Qâf    50   40
# 6                   The Pilgrimage    22   46
# 7                 The Overthrowing    81   18
# 8           The Rising of the Dead    75    3
# 9                          Al-Hijr    15   43
#
#                                               Arabic  \
# 0  فَلاَ تُعْجِبْكَ أَمْوَٰلُهُمْ وَلاَ أَوْلَـٰد...
# 1  وَضَلَّ عَنْهُم مَّا كَانُواْ يَدْعُونَ مِن قَ...
# 2  فَأَمَّا ٱلَّذِينَ آمَنُواْ وَعَمِلُواْ ٱلصَّا...
# 3              وَنَعْمَةٍ كَانُواْ فِيهَا فَاكِهِينَ
# 4                        إِلاَّ أَصْحَابَ ٱلْيَمِينِ
# 5  وَمِنَ ٱللَّيْلِ فَسَبِّحْهُ وَأَدْبَارَ ٱلسُّ...
# 6  أَفَلَمْ يَسِيرُواْ فِي ٱلأَرْضِ فَتَكُونَ لَه...
# 7                        وَٱلصُّبْحِ إِذَا تَنَفَّسَ
# 8   أَيَحْسَبُ ٱلإِنسَانُ أَلَّن نَّجْمَعَ عِظَامَهُ
# 9       وَإِنَّ جَهَنَّمَ لَمَوْعِدُهُمْ أَجْمَعِينَ
#
#                                   EnglishTranslation  \
# 0  Let not their wealth nor their (following in) ...
# 1  The (deities) they used to invoke aforetime wi...
# 2  Then, as to those who believed and did righteo...
# 3  And wealth (and conveniences of life), wherein...
# 4           Except the Companions of the Right Hand.
# 5  And during part of the night, (also,) celebrat...
# 6  Do they not travel through the land, so that t...
# 7    And the Dawn as it breathes away the darkness;-
# 8  Does man think that We cannot assemble his bones?
# 9  And verily, Hell is the promised abode for the...
#
#                                              Tafseer     Score
# 0  b'54. \x93Allah only intends to punish them th...  0.694461
# 1  b'70. This verse has two meanings and both hav...  0.657000
# 2  b'46. This last sentence depicts the manner of...  0.649723
# 3  b'28. That is, Allah was well aware both of th...  0.646379
# 4  b'34. This shows how grave a sin it is in Isla...  0.644642
# 5  b'55. In this sentence there is consolation fo...  0.642098
# 6  b'91. The words \x93blinded are the hearts\x94...  0.639953
# 7  b'19. (In Surah An-Najm, Ayats 7-9), this obse...  0.638221
# 8  b'There is no commentary by Abul Maududi avail...  0.635078
# 9  b'25. In order to comprehend the purpose for w...  0.634897

# %%
SearchDocument("What is the punishment for sin?")
# Out:
# 1it [00:00, 436.50it/s]
#                       Name Surah Ayat  \
# 0           The Beneficent    55   35
# 1           The Pilgrimage    22   37
# 2              The Tidings    78    5
# 3                 The Cave    18   86
# 4                 The Moon    54   26
# 5          The Prostration    32   30
# 6  The Ascending Stairways    70    8
# 7                   Joseph    12   55
# 8                    Jonah    10   66
# 9                    Smoke    44   37
#
#                                               Arabic  \
# 0  يُرْسَلُ عَلَيْكُمَا شُوَاظٌ مِّن نَّارٍ وَنُح...
# 1  لَن يَنَالَ ٱللَّهَ لُحُومُهَا وَلاَ دِمَآؤُهَ...
# 2                         ثُمَّ كَلاَّ سَيَعْلَمُونَ
# 3  حَتَّىٰ إِذَا بَلَغَ مَغْرِبَ ٱلشَّمْسِ وَجَدَ...
# 4     سَيَعْلَمُونَ غَداً مَّنِ ٱلْكَذَّابُ ٱلأَشِرُ
# 5  فَأَعْرِضْ عَنْهُمْ وَٱنتَظِرْ إِنَّهُمْ مُّنت...
# 6              يَوْمَ تَكُونُ ٱلسَّمَآءُ كَٱلْمُهْلِ
# 7  قَالَ ٱجْعَلْنِي عَلَىٰ خَزَآئِنِ ٱلأَرْضِ إِن...
# 8  أَلاۤ إِنَّ لِلَّهِ مَن فِي ٱلسَّمَٰوَٰت وَمَن...
# 9  أَهُمْ خَيْرٌ أَمْ قَوْمُ تُبَّعٍ وَٱلَّذِينَ ...
#
#                                   EnglishTranslation  \
# 0  On you will be sent (O ye evil ones twain!) a ...
# 1  It is not their meat nor their blood, that rea...
# 2     Verily, verily they shall soon (come to) know!
# 3  Until, when he reached the setting of the sun,...
# 4  Ah! they will know on the morrow, which is the...
# 5  So turn away from them, and wait: they too are...
# 6    The Day that the sky will be like molten brass,
# 7  (Joseph) said: "Set me over the store-houses o...
# 8  Behold! verily to Allah belong all creatures, ...
# 9  What! Are they better than the people of Tubba...
#
#                                              Tafseer     Score
# 0  b'37. The real basis of the crime according to...  0.656977
# 1  b'73. This prescribes a very important conditi...  0.642805
# 2  b'There is no commentary by Abul Maududi avail...  0.642728
# 3  b'63. \x93The setting place of the sun\x94 doe...  0.637792
# 4  b'21. The crushed and rotten bodies of the peo...  0.637640
# 5  b'There is no commentary by Abul Maududi avail...  0.616478
# 6  b'There is no commentary by Abul Maududi avail...  0.613956
# 7  b'There is no commentary by Abul Maududi avail...  0.613302
# 8  b'There is no commentary by Abul Maududi avail...  0.611582
# 9  b'37. These sentences portray the nature of th...  0.610886

# %% [markdown]
# # Similarity Index

# %% [markdown]
# ## TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Create TfidfVectorizer object
vectorizer = TfidfVectorizer()

# Generate matrix of word vectors
tfidf_matrix = vectorizer.fit_transform(df['Keyword_final'].values.astype('str'))

# Print the shape of tfidf_matrix
print(tfidf_matrix.shape)
# Out:
# (6236, 12030)

# %%
# Initialize an instance of tf-idf Vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Generate the tf-idf vectors for the corpus
tfidf_matrix = tfidf_vectorizer.fit_transform(df['Keyword_final'].values.astype('str'))

# compute and print the cosine similarity matrix
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
print(cosine_sim)
# Out:
# [[1.         0.08501035 0.04205995 ... 0.         0.         0.        ]
#  [0.08501035 1.         0.12877372 ... 0.         0.         0.        ]
#  [0.04205995 0.12877372 1.         ... 0.         0.         0.        ]
#  ...
#  [0.         0.         0.         ... 1.         0.58239107 0.09286464]
#  [0.         0.         0.         ... 0.58239107 1.         0.12180621]
#  [0.         0.         0.         ... 0.09286464 0.12180621 1.        ]]

# %%
def most_similar_tfidf(cosine_sim, ind):
    return cosine_sim[ind].argsort()[-10:][::-1]

# %%
ayat = 10
print("Tafseers most closely related to ayat", ayat,"of Quran")
df.iloc[most_similar_tfidf(cosine_sim, ayat)]
# Out:
# Tafseers most closely related to ayat 10 of Quran
#                            Name  Surah  Ayat  \
# 10                      The Cow      2     4
# 879                      Cattle      6    91
# 2887              The Criterion     25    33
# 3525            The Prostration     32    23
# 298        The Family of 'Imrân      3     6
# 880                      Cattle      6    92
# 1707                The Thunder     13     1
# 716            The Table Spread      5    48
# 3300                  The Story     28    49
# 4541  The Wind-Curved Sandhills     46    32
#
#                                                  Arabic  \
# 10    وٱلَّذِينَ يُؤْمِنُونَ بِمَآ أُنْزِلَ إِلَيْكَ...
# 879   وَمَا قَدَرُواْ ٱللَّهَ حَقَّ قَدْرِهِ إِذْ قَ...
# 2887  وَلاَ يَأْتُونَكَ بِمَثَلٍ إِلاَّ جِئْنَاكَ بِ...
# 3525  وَلَقَدْ آتَيْنَا مُوسَى ٱلْكِتَابَ فَلاَ تَكُ...
# 298   هُوَ ٱلَّذِي يُصَوِّرُكُمْ فِي ٱلأَرْحَامِ كَي...
# 880   وَهَـٰذَا كِتَٰبٌ أَنزَلْنَٰهُ مُبَارَكٌ مُّصَ...
# 1707  الۤمۤر تِلْكَ آيَاتُ ٱلْكِتَابِ وَٱلَّذِيۤ أُن...
# 716   وَأَنزَلْنَآ إِلَيْكَ ٱلْكِتَابَ بِٱلْحَقِّ مُ...
# 3300  قُلْ فَأْتُواْ بِكِتَابٍ مِّنْ عِندِ ٱللَّهِ ه...
# 4541  وَمَن لاَّ يُجِبْ دَاعِيَ ٱللَّهِ فَلَيْسَ بِم...
#
#                                      EnglishTranslation  \
# 10    And who believe in the Revelation sent to thee...
# 879   No just estimate of Allah do they make when th...
# 2887  And no question do they bring to thee but We r...
# 3525  We did indeed aforetime give the Book to Moses...
# 298   He it is Who shapes you in the wombs as He ple...
# 880   And this is a Book which We have sent down, br...
# 1707  A. L. M. R. These are the signs (or verses) of...
# 716   To thee We sent the Scripture in truth, confir...
# 3300  Say: "Then bring ye a Book from Allah, which i...
# 4541  "If any does not hearken to the one who invite...
#
#                                                 Tafseer  \
# 10    b'7. The fifth requirement is that one should ...
# 879   b'59. In the light of the foregoing discussion...
# 2887  b'46. This is yet another point of wisdom of s...
# 3525  b'35. The address apparently is to the Prophet...
# 298   b'4. This refers to two important facts. The f...
# 880   b'61. The point argued above was that God\x92s...
# 1707  b'1. This is the introduction to this Surah, i...
# 716   b'78. This points to a fact of major significa...
# 3300  b'70. That is, \x93I have to follow the guidan...
# 4541  b'4. Although after saying alladhina amanu (th...
#
#                                             useful_info  \
# 10    and who believe in the revelation sent to thee...
# 879   no just estimate of allah do they make when th...
# 2887  and no question do they bring to thee but we r...
# 3525  we did indeed aforetime give the book to moses...
# 298   he it is who shapes you in the wombs as he ple...
# 880   and this is a book which we have sent down bri...
# 1707  a. l. m. r. these are the signs or verses of t...
# 716   to thee we sent the scripture in truth confirm...
# 3300  say then bring ye a book from allah which is a...
# 4541  if any does not hearken to the one who invites...
#
#                                           info_tokenize  \
# 10    [and, who, believe, in, the, revelation, sent,...
# 879   [no, just, estimate, of, allah, do, they, make...
# 2887  [and, no, question, do, they, bring, to, thee,...
# 3525  [we, did, indeed, aforetime, give, the, book, ...
# 298   [he, it, is, who, shapes, you, in, the, wombs,...
# 880   [and, this, is, a, book, which, we, have, sent...
# 1707  [a., l., m., r., these, are, the, signs, or, v...
# 716   [to, thee, we, sent, the, scripture, in, truth...
# 3300  [say, then, bring, ye, a, book, from, allah, w...
# 4541  [if, any, does, not, hearken, to, the, one, wh...
#
#                                           Keyword_final
# 10    believe,revelation,send,thee,send,thy,time,hea...
# 879   estimate,allah,make,say,nothing,doth,allah,sen...
# 2887  question,bring,thee,reveal,thee,truth,best,exp...
# 3525  indeed,aforetime,give,book,moses,doubt,reach,t...
# 298   shape,womb,please,god,exalt,might,refers,two,i...
# 880   book,send,bring,blessing,confirm,revelation,co...
# 1707  sign,verse,book,hath,reveal,unto,thee,thy,lord...
# 716   thee,send,scripture,truth,confirm,scripture,co...
# 3300  say,bring,ye,book,allah,good,guide,either,may,...
# 4541  hearken,one,invite,u,allah,frustrate,allah,pla...
